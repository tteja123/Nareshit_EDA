# %% [markdown]
# ## Data Transformation Techniques
#
# - Generally used for to convert Normal distribution
# - Because all statistical math analysis by assumption Data follows Normal distribution
# - It is also avoid skewness also
# - We have some important transformation
#     - Log Transformation
#     - Exponential Transformation
#     - Reciprocal Transformation
#     - Square root Transformation
#     - Power Transformation

# %% [markdown]
# $Step-1$
#
# **Read the required packages**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $Step-2$
#
# **Read the data**
#
# $Exponential-data$

# %%
exp_data = np.random.exponential(size = 10000)
exp_data[:10]

## we are consider exponential data set with random 1k observations 
## using numpy package
# Out:
# array([0.76344322, 6.58574417, 1.43730399, 1.30590188, 1.04858922,
#        0.09866278, 1.08188487, 3.12771717, 0.04508498, 0.20628858])

# %%
plt.hist(exp_data, bins = 30, label = "Exponential")
plt.legend()
plt.show()

# %% [markdown]
# $Norm-data$

# %%
norm_data = np.random.normal(size = 1000)
plt.hist(norm_data)
plt.show()

# %% [markdown]
# $Step-3$
#
# **Log Transformation**
#
# - np.log is used for log transformation
# - Generally log transformation will not convert data into normal
# - It avoids skew ness
# - np.log means natural logorithm base = e

# %%
x =2
import numpy as np
np.log(2)
# Out:
# 0.6931471805599453

# %%
log_data = np.log(exp_data)
log_data[:10]
# Out:
# array([-0.26991652,  1.88490734,  0.36276913,  0.2668939 ,  0.04744566,
#        -2.3160475 ,  0.07870477,  1.1403034 , -3.09920607, -1.57847921])

# %%
exp_data[:10]
# Out:
# array([0.76344322, 6.58574417, 1.43730399, 1.30590188, 1.04858922,
#        0.09866278, 1.08188487, 3.12771717, 0.04508498, 0.20628858])

# %%
plt.hist(log_data, bins = 40, label = "Log data")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1).hist(exp_data,
                       bins = 40,
                       label = "Exponential")
plt.legend()
plt.subplot(1,2,2).hist(log_data,
                       bins = 40,
                       label = "Log transformation")
plt.legend()
plt.show()

# %% [markdown]
# $Step-4$
#
# **Reciprocal transformation**
#
# - reciprocal transformation falls when data has zero value

# %%
# take the exponnetial data
# rec_data = 1/exp_data
# plat the histogram and check it

# %%
x = 3
np.reciprocal(x)
# Out:
# 0

# %%
1/0.77
# Out:
# 1.2987012987012987

# %%
exp_data, rec_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 exp_data, rec_data
#
# NameError: name 'rec_data' is not defined
