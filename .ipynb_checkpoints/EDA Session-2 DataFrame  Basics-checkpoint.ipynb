# %% [markdown]
# # Import Packages

# %%
i am updating the file

# %%
a = 20
b = 34
print(a+b)
# Out:
# 54

# %%
print(a-b)
# Out:
# -14

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $ Reading CSV file $

# %%
path = "C:\\Users\\chand\\Onedrive\\Documents\\datascience\\Python Data files for Analysis\\Visadataset.csv"
df = pd.read_csv(path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $ Head $

# %%
df.head() ###   First 5 rows by default
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# $ Tail $

# %%
df.tail()  ## Last 5 rows By default
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $ Shape $

# %%
df.shape  ## Number of rows and columns
# Out:
# (25480, 12)

# %%
print("The number of rows are: ",df.shape[0])
print("The number of columns are: ",df.shape[1])
# Out:
# The number of rows are:  25480
# The number of columns are:  12

# %% [markdown]
# $ Size $

# %% [markdown]
# **How many indices are there provided by size**

# %%
df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %% [markdown]
# $Columns$

# %%
df.columns  #3 All the column values
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$

# %% [markdown]
# **Data Types**

# %%
df.dtypes 

## Object means categorical
#3 otherthan object numerical(Int or float)
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Task-1

# %% [markdown]
# **extract numerical columns and categorical columns separately by using dtypes output**

# %%
#3 Convert above into dict(Key and value)
## By using if for and list

d1 = dict(df.dtypes)
#for i in d1:
#    if d1[i] == "object":
#        print(i)
cat = [i for i in d1 if d1[i] == "object"]
num = [i for i in d1 if d1[i] != "object"]

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
## Categorical data available

df.select_dtypes(include = "object")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
df.select_dtypes(include = "object").columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.select_dtypes(exclude = 'object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
df.select_dtypes(exclude = "object").columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#3 df has 12 columns
## df.select_dtypes(include = "object") has 9 columns
#3 df.select_dtypes(exclude = "object") has 3 columns

# %% [markdown]
# $isnull$
#
# **identify if data has missing values or Null values**

# %%
df.isnull()  #3 It will give true or false

#3 True means null value is there
#3 False means null value is not there
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
## when we open excel sheet the data has empty
#3 whuch means that data is missed
#3 when you read that using pandas
#3 at that particular position it displays as null

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $drop$ $duplicates$
#
# **Drop Duplicate Values**

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
len(df)
# Out:
# 25480

# %% [markdown]
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes
# - isnull
# - isnull().sum()
# - drop duplicates
# - info
# - len

# %% [markdown]
# **Bound Method**
#
#    - you need to keep brackets
#
# **Not Callable**
#
#    - you need to remove the brackets
#
# **Attribute error**
#
#    - the method is not available
#    - check the spell mistake

# %%
# we want to read sample of data
# we know head will give top 5
# we know tail will give bottom 5
# if you want specific rows or columns

# %% [markdown]
# $take$-$loc$-$iloc$

# %%
df.take((2,5,7))

#3 2,5,7 are the columns or rows
# axis = 1 refer to columns
# axis = 0 refer to rows
# by default  axis = 0, rows
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 2  EZYV03           Asia            Bachelor's                  N
# 5  EZYV06           Asia              Master's                  Y
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 5                     N             2339         2012                South
# 7                     N             3035         1924                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2      122996.8600         Year                  Y      Denied
# 5       78252.1400         Year                  Y   Certified
# 7         418.2298         Hour                  Y      Denied

# %%
df.take([2,3,4],axis =1)
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
df.take([200,300,400]).take([4,8,11],axis = 1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified
# 400                     N        113927.99   Certified

# %% [markdown]
# **take does not take rows and columns at a time**

# %% [markdown]
# $iloc$

# %%
# df.iloc[<rows>,<column>]
# df.iloc[<start:end>,<start:end>]
# rows = []
# columns = []
# df.iloc[rows,columns]

# %%
df.iloc[5:8] #3 all the colmns
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
# 7                     N             3035         1924                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5       78252.1400         Year                  Y   Certified
# 6       53635.3900         Year                  Y   Certified
# 7         418.2298         Hour                  Y      Denied

# %%
df.iloc[5,8] #3 specific rows and column
# Out:
# 78252.14

# %%
df.iloc[5:15,2:5]
# Out:
#    education_of_employee has_job_experience requires_job_training
# 5               Master's                  Y                     N
# 6             Bachelor's                  N                     N
# 7             Bachelor's                  Y                     N
# 8             Bachelor's                  N                     N
# 9              Doctorate                  Y                     N
# 10              Master's                  N                     N
# 11           High School                  Y                     N
# 12            Bachelor's                  Y                     N
# 13            Bachelor's                  Y                     N
# 14              Master's                  Y                     Y

# %%
df.iloc[:,2:5] #3 all the rows
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.iloc[5,8] #3 specific rows and column
df.iloc[5:8] #3 all the colmns
df.iloc[:,2:5] #3 all the rows

# %%
df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
df.iloc[[100,200,300],[4,8,11]]
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#3 Only prevailing wage 

df.iloc[[100,200,300],[8]]

## No bracket : series
# bracket is there data frame
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
## only full time

df.iloc[[100,200,300],[10]]

#3 iloc will consider column index
# Out:
#     full_time_position
# 100                  Y
# 200                  Y
# 300                  Y

# %% [markdown]
# $loc$

# %%
df.loc[[200,300,400],['full_time_position']]

#3 loc will consider directly column name
# Out:
#     full_time_position
# 200                  Y
# 300                  Y
# 400                  Y

# %%
#3 df.loc[[200,300,400],[10]]  will give error
